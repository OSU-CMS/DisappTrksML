# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
dataDir = 'c:/Users/llave/Documents/CMS/data/'
bkg_files = glob.glob(dataDir+'genMuons_bkg_v7/*.root.npz')
signal_files = bkg_files
muon_files = [dataDir+'nonRecoGenMuons_v6_V3.npz']
probe_files = glob.glob(dataDir+'SingleMuon_2017F_v7/*.root.npz')
reco_probe_files = glob.glob(dataDir+'SingleMuon_2017F_v7/*.root.npz')

def load_data(files, nFiles, sets_name, info_name):
    sets, infos = None, None
    for file in files[:nFiles]:
        indata = np.load(file, allow_pickle=True)[sets_name]
        if indata.shape[0] == 0: continue
        if sets is None: sets = indata
        else: sets = np.vstack((sets,indata))
            
        indata = np.load(file, allow_pickle=True)[info_name]
        if infos is None: infos = indata
        else: infos = np.vstack((infos,indata))
            
    obj = {'sets':sets, 'infos':infos}
    return obj
    
trainBackground = load_data(bkg_files, 20, 'background', 'background_info')
# trainSignal = load_data(signal_files, 20, 'signal', 'signal_info')
# recoFailMuonsDY = load_data(muon_files, len(muon_files), 'signal', 'infos')
recoFailMuonsData = load_data(probe_files, len(probe_files), 'sets', 'infos')
# recoMuonsData = load_data(reco_probe_files, 20, 'sets', 'infos')

# %%
events = recoFailMuonsData['sets']
infos = recoFailMuonsData['infos']
event = events[np.where(infos[:,0] == 27491809)][0,:,:]
plt.scatter(event[:,0], event[:,1])
plt.xlim(-0.3,0.3)
plt.ylim(-0.3,0.3)
# Out:
# (-0.3, 0.3)

# %%
trainBackgroundPlot = {
    "density":True,
    "label":"Background (MC)",
    "histtype":'step',
    "edgecolor":'black'
}
trainSignalPlot = {
    "density":True,
    "label":"Gen Muons, Reconstructed (MC)",
    "histtype":'step',
    "edgecolor":'red'
}
recoFailMuonsDYPlot = {
    "density":True,
    "label":"Gen Muons, Non-Reco. (MC)",
    "histtype":'step',
    "edgecolor":'blue'
}
recoFailMuonsDataPlot = {
    "density":True,
    "label":"T+P Tracks, Non-Reco. (Data)",
    "histtype":'step',
    "edgecolor":'green'
}
recoMuonsDataPlot = {
    "density":True,
    "label":"T+P Tracks, Reconstructed (Data)",
    "histtype":'step',
    "edgecolor":'magenta'
}

# %%
def count_hits_per_event(events):
    array = []
    for event in events:
        nParticles = np.count_nonzero(event[:,2])
        array.append(nParticles)
    return array

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)
ax.hist(count_hits_per_event(trainBackground['sets']),bins=np.linspace(0,20,20),**trainBackgroundPlot)
ax.hist(count_hits_per_event(trainSignal['sets']),bins=np.linspace(0,20,20),**trainSignalPlot)
ax.hist(count_hits_per_event(recoFailMuonsDY['sets']),bins=np.linspace(0,20,20),**recoFailMuonsDYPlot)
ax.hist(count_hits_per_event(recoFailMuonsData['sets']),bins=np.linspace(0,20,20),**recoFailMuonsDataPlot)
ax.hist(count_hits_per_event(recoMuonsData['sets']),bins=np.linspace(0,20,20),**recoMuonsDataPlot)

ax.set_xlabel("Number of hits in MUO")
ax.legend()
ax.set_yscale('log')

fig.tight_layout()
fig.savefig("../plots/nhits.png")

# %%
def perHit_info(data):

    dEtas, dPhis = [], []
    stations = []
    times = []

    for event, info in zip(data['sets'],data['infos']):
        for hit in event:
            if np.sum(hit) == 0: continue
            dEtas.append(hit[0])
            dPhis.append(hit[1])
            stations.append(hit[2])
            times.append(hit[3])
            
    return dEtas, dPhis, stations, times

# dEtas_sig, dPhis_sig, stations_sig, times_sig = perHit_info(trainSignal)
dEtas_bkg, dPhis_bkg, stations_bkg, times_bkg = perHit_info(trainBackground)
# dEtas_recoFailMuonsDY, dPhis_recoFailMuonsDY, stations_recoFailMuonsDY, times_recoFailMuonsDY = perHit_info(recoFailMuonsDY)
dEtas_recoFailMuonsData, dPhis_recoFailMuonsData, stations_recoFailMuonsData, times_recoFailMuonsData = perHit_info(recoFailMuonsData)
# dEtas_recoMuonsData, dPhis_recoMuonsData, stations_recoMuonsData, times_recoMuonsData = perHit_info(recoMuonsData)

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 4))

im0 = ax[0].hist2d(dEtas_sig,dPhis_sig,bins=50)
ax[0].set_title("Distance from track")
ax[0].set_xlabel(r"$\eta$")
ax[0].set_ylabel(r"$\phi$")
fig.colorbar(im0[3], ax=ax[0])

im1 = ax[1].hist2d(trainSignal['infos'][:,8],trainSignal['infos'][:,9],bins=40)
ax[1].set_title("Absolute Coords")
ax[1].set_xlabel(r"$\eta$")
ax[1].set_ylabel(r"$\phi$")
fig.colorbar(im1[3], ax=ax[1])

fig.tight_layout()
fig.savefig('../plots/trainSignal_coords.png')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 4))

im0 = ax[0].hist2d(dEtas_bkg,dPhis_bkg,bins=50)
ax[0].set_title("Distance from track")
ax[0].set_xlabel(r"$d\eta$")
ax[0].set_ylabel(r"$d\phi$")
fig.colorbar(im0[3], ax=ax[0])

im1 = ax[1].hist2d(trainBackground['infos'][:,8],trainBackground['infos'][:,9],bins=40)
ax[1].set_title("Absolute Coords")
ax[1].set_xlabel(r"$\eta$")
ax[1].set_ylabel(r"$\phi$")
fig.colorbar(im1[3], ax=ax[1])

plt.tight_layout()
fig.savefig('../plots/trainBackground_coords.png')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 4))

im0 = ax[0].hist2d(dEtas_recoFailMuonsDY,dPhis_recoFailMuonsDY,bins=50)
ax[0].set_title("Distance from track")
ax[0].set_xlabel(r"$d\eta$")
ax[0].set_ylabel(r"$d\phi$")
fig.colorbar(im0[3], ax=ax[0])

im1 = ax[1].hist2d(recoFailMuonsDY['infos'][:,8],recoFailMuonsDY['infos'][:,9],bins=40)
ax[1].set_title("Absolute Coords")
ax[1].set_xlabel(r"$\eta$")
ax[1].set_ylabel(r"$\phi$")
fig.colorbar(im1[3], ax=ax[1])

plt.tight_layout()
fig.savefig('../plots/recoFailMuonsDY_coords.png')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 4))

im0 = ax[0].hist2d(dEtas_recoFailMuonsData,dPhis_recoFailMuonsData,bins=50)
ax[0].set_title("Distance from track")
ax[0].set_xlabel(r"$d\eta$")
ax[0].set_ylabel(r"$d\phi$")
fig.colorbar(im0[3], ax=ax[0])

im1 = ax[1].hist2d(recoFailMuonsData['infos'][:,8],recoFailMuonsData['infos'][:,9],bins=40)
ax[1].set_title("Absolute Coords")
ax[1].set_xlabel(r"$\eta$")
ax[1].set_ylabel(r"$\phi$")
fig.colorbar(im1[3], ax=ax[1])

plt.tight_layout()
fig.savefig('../plots/recoFailMuonsData_coords.png')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 4))

im0 = ax[0].hist2d(dEtas_recoMuonsData,dPhis_recoMuonsData,bins=50)
ax[0].set_title("Distance from track")
ax[0].set_xlabel(r"$d\eta$")
ax[0].set_ylabel(r"$d\phi$")
fig.colorbar(im0[3], ax=ax[0])

im1 = ax[1].hist2d(recoMuonsData['infos'][:,8],recoMuonsData['infos'][:,9],bins=40)
ax[1].set_title("Absolute Coords")
ax[1].set_xlabel(r"$\eta$")
ax[1].set_ylabel(r"$\phi$")
fig.colorbar(im1[3], ax=ax[1])

plt.tight_layout()
fig.savefig('../plots/recoMuonsData_coords.png')

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_subplot(1,1,1)
ax.hist(trainSignal['infos'][:,8], bins=100,**trainSignalPlot)
ax.hist(trainBackground['infos'][:,8], bins=100,**trainBackgroundPlot)
ax.hist(recoFailMuonsDY['infos'][:,8], bins=100,**recoFailMuonsDYPlot)
ax.hist(recoFailMuonsData['infos'][:,8], bins=100,**recoFailMuonsDataPlot)
ax.hist(recoMuonsData['infos'][:,8], bins=100,**recoMuonsDataPlot)

ax.set_xlabel(r"$\eta$")
ax.legend()

fig.savefig("../plots/eta.png")

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_subplot(1,1,1)
ax.hist(trainSignal['infos'][:,9], bins=100,**trainSignalPlot)
ax.hist(trainBackground['infos'][:,9], bins=100,**trainBackgroundPlot)
ax.hist(recoFailMuonsDY['infos'][:,9], bins=50,**recoFailMuonsDYPlot)
ax.hist(recoFailMuonsData['infos'][:,9], bins=50,**recoFailMuonsDataPlot)
ax.hist(recoMuonsData['infos'][:,9], bins=100,**recoMuonsDataPlot)

ax.set_xlabel(r"$\phi$")
ax.legend()

fig.savefig("../plots/phi.png")

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].hist(trainSignal['infos'][:,11], bins=np.linspace(0,20,20), **trainSignalPlot)
ax[0].hist(trainBackground['infos'][:,11], bins=np.linspace(0,20,20), **trainBackgroundPlot)
ax[0].hist(recoFailMuonsDY['infos'][:,11], bins=np.linspace(0,20,20), **recoFailMuonsDYPlot)
ax[0].hist(recoFailMuonsData['infos'][:,11], bins=np.linspace(0,20,20), **recoFailMuonsDataPlot)
ax[0].hist(recoMuonsData['infos'][:,11], bins=np.linspace(0,20,20), **recoMuonsDataPlot)
ax[0].set_xlabel("nLayersWithMeasurement")
ax[0].legend()
ax[1].hist(trainSignal['infos'][:,12], bins=np.linspace(0,10,10),**trainSignalPlot)
ax[1].hist(trainBackground['infos'][:,12], bins=np.linspace(0,10,10), **trainBackgroundPlot)
ax[1].hist(recoFailMuonsDY['infos'][:,12], bins=np.linspace(0,10,10), **recoFailMuonsDYPlot)
ax[1].hist(recoFailMuonsData['infos'][:,12], bins=np.linspace(0,10,10), **recoFailMuonsDataPlot)
ax[1].hist(recoMuonsData['infos'][:,12], bins=np.linspace(0,10,10), **recoMuonsDataPlot)
ax[1].set_xlabel("nValidPixelHits")
ax[1].legend()

fig.tight_layout()
fig.savefig("../plots/pixel_hits.png")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

# ax.hist(times_sig, bins=100, **trainSignalPlot)
ax.hist(times_bkg, bins=100, **trainBackgroundPlot)
# ax.hist(times_recoFailMuonsDY, bins=100, **recoFailMuonsDYPlot)
ax.hist(times_recoFailMuonsData, bins=100, **recoFailMuonsDataPlot)
# ax.hist(times_recoMuonsData, bins=100, **recoMuonsDataPlot)

ax.set_xlabel("Time [ns]")
ax.set_yscale('log')
ax.legend()

fig.tight_layout()
# fig.savefig("../plots/time.png")

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))

ax[0].hist(trainSignal['infos'][:,13], bins=100, **trainSignalPlot)
ax[0].hist(trainBackground['infos'][:,13], bins=100, **trainBackgroundPlot)
ax[0].hist(recoFailMuonsDY['infos'][:,13], bins=100, **recoFailMuonsDYPlot)
ax[0].hist(recoFailMuonsData['infos'][:,13], bins=100, **recoFailMuonsDataPlot)
ax[0].hist(recoMuonsData['infos'][:,13], bins=100, **recoMuonsDataPlot)
ax[0].set_title(r"Sum of ECAL Energy within $\Delta R < 0.1$")
ax[0].set_yscale('log')
ax[0].set_xscale('log')
ax[0].legend()
ax[1].hist(trainSignal['infos'][:,14], bins=100, **trainSignalPlot)
ax[1].hist(trainBackground['infos'][:,14], bins=100, **trainBackgroundPlot)
ax[1].hist(recoFailMuonsDY['infos'][:,14], bins=100, **recoFailMuonsDYPlot)
ax[1].hist(recoFailMuonsData['infos'][:,14], bins=100, **recoFailMuonsDataPlot)
ax[1].hist(recoMuonsData['infos'][:,14], bins=100, **recoMuonsDataPlot)
ax[1].set_title(r"Sum of HCAL Energy within $\Delta R < 0.1$")
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].legend()

fig.tight_layout()
fig.savefig("../plots/ecal_hcal.png")

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
ax[0].hist(trainSignal['infos'][:,20], bins=100, **trainSignalPlot)
ax[0].hist(trainBackground['infos'][:,20], bins=100, **trainBackgroundPlot)
ax[0].hist(recoFailMuonsDY['infos'][:,20], bins=20, **recoFailMuonsDYPlot)
ax[0].hist(recoFailMuonsData['infos'][:,20], bins=20, **recoFailMuonsDataPlot)
ax[0].hist(recoMuonsData['infos'][:,20], bins=100, **recoMuonsDataPlot)
ax[0].set_xlabel(r"dz")
ax[0].set_yscale('log')
# ax[0].set_xscale('log')
ax[0].legend()
ax[1].hist(trainSignal['infos'][:,21], bins=100, **trainSignalPlot)
ax[1].hist(trainBackground['infos'][:,21], bins=100, **trainBackgroundPlot)
ax[1].hist(recoFailMuonsDY['infos'][:,21], bins=20, **recoFailMuonsDYPlot)
ax[1].hist(recoFailMuonsData['infos'][:,21], bins=20, **recoFailMuonsDataPlot)
ax[1].hist(recoMuonsData['infos'][:,21], bins=100, **recoMuonsDataPlot)
ax[1].set_xlabel(r"d0")
ax[1].set_yscale('log')
# ax[1].set_xscale('log')
ax[1].legend()

fig.tight_layout()
fig.savefig("../plots/dz_d0.png")

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
ax[0].hist(trainSignal['infos'][:,18], bins=100, **trainSignalPlot)
ax[0].hist(trainBackground['infos'][:,18], bins=100, **trainBackgroundPlot)
ax[0].hist(recoFailMuonsDY['infos'][:,18], bins=10, **recoFailMuonsDYPlot)
ax[0].hist(recoFailMuonsData['infos'][:,18], bins=10, **recoFailMuonsDataPlot)
ax[0].hist(recoMuonsData['infos'][:,18], bins=100, **recoMuonsDataPlot)
ax[0].set_xlabel(r"$\frac{dE}{dx}\;Pixel$")
ax[0].set_yscale('log')
ax[0].set_xscale('log')
ax[0].legend()
ax[1].hist(trainSignal['infos'][:,19], bins=100, **trainSignalPlot)
ax[1].hist(trainBackground['infos'][:,19], bins=100, **trainBackgroundPlot)
ax[1].hist(recoFailMuonsDY['infos'][:,19], bins=10, **recoFailMuonsDYPlot)
ax[1].hist(recoFailMuonsData['infos'][:,19], bins=10, **recoFailMuonsDataPlot)
ax[1].hist(recoMuonsData['infos'][:,19], bins=100, **recoMuonsDataPlot)
ax[1].set_xlabel(r"$\frac{dE}{dx}\;Strip$")
ax[1].set_yscale('log')
# ax[1].set_xscale('log')
ax[1].legend()

fig.tight_layout()

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_subplot(1,1,1)
ax.hist(trainSignal['infos'][:,4], bins=20,**trainSignalPlot)
ax.hist(trainBackground['infos'][:,4], bins=20,**trainBackgroundPlot)
ax.hist(recoFailMuonsDY['infos'][:,4], bins=20,**recoFailMuonsDYPlot)
ax.hist(recoFailMuonsData['infos'][:,4], bins=20,**recoFailMuonsDataPlot)
ax.hist(recoMuonsData['infos'][:,4], bins=20,**recoMuonsDataPlot)

ax.set_xlabel(r"nPV")
# ax.set_yscale('log')
ax.legend()

fig.tight_layout()

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_subplot(1,1,1)
ax.hist(trainSignal['infos'][:,17], bins=np.linspace(0,10,10),**trainSignalPlot)
ax.hist(trainBackground['infos'][:,17], bins=np.linspace(0,10,10),**trainBackgroundPlot)
ax.hist(recoFailMuonsDY['infos'][:,17], bins=np.linspace(0,10,10),**recoFailMuonsDYPlot)
ax.hist(recoFailMuonsData['infos'][:,17], bins=np.linspace(0,10,10),**recoFailMuonsDataPlot)
ax.hist(recoMuonsData['infos'][:,17], bins=np.linspace(0,10,10),**recoMuonsDataPlot)

ax.set_xlim(0,10)
ax.set_xlabel(r"Normalized $\chi^2$")
# ax.set_yscale('log')
ax.legend()

fig.tight_layout()

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_subplot(1,1,1)
ax.hist(np.divide(trainBackground['infos'][:,16], trainBackground['infos'][:,15]), bins=np.linspace(0,3,100),**trainSignalPlot)
ax.hist(np.divide(trainSignal['infos'][:,16], trainSignal['infos'][:,15]), bins=np.linspace(0,3,100),**trainBackgroundPlot)
ax.hist(np.divide(recoFailMuonsDY['infos'][:,16], recoFailMuonsDY['infos'][:,15]), bins=np.linspace(0,3,100),**recoFailMuonsDYPlot)
ax.hist(np.divide(recoFailMuonsData['infos'][:,16], recoFailMuonsData['infos'][:,15]), bins=np.linspace(0,3,100),**recoFailMuonsDataPlot)
ax.hist(np.divide(recoMuonsData['infos'][:,16], recoMuonsData['infos'][:,15]), bins=np.linspace(0,3,100),**recoMuonsDataPlot)

plt.xlabel(r"$Error_{p_T} / p_T$")
plt.yscale('log')
plt.xlim(0,3)
# plt.xscale('log')
plt.legend()

fig.tight_layout()

print(np.sum(np.divide(trainBackground['infos'][:,16], trainBackground['infos'][:,15]) > 3)/len(trainBackground['infos']))
print(np.sum(np.divide(trainSignal['infos'][:,16], trainSignal['infos'][:,15]) > 3)/len(trainSignal['infos']))
print(np.sum(np.divide(recoFailMuonsDY['infos'][:,16], recoFailMuonsDY['infos'][:,15]) > 3)/len(recoFailMuonsDY['infos']))
print(np.sum(np.divide(recoFailMuonsData['infos'][:,16], recoFailMuonsData['infos'][:,15]) > 3)/len(recoFailMuonsData['infos']))
print(np.sum(np.divide(recoMuonsData['infos'][:,16], recoMuonsData['infos'][:,15]) > 3)/len(recoMuonsData['infos']))
# Out:
# 0.1682914863640938
# 0.001023029132181511
# 0.05
# 0.028368794326241134
# 0.0

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_subplot(1,1,1)
ax.hist(trainSignal['infos'][:,6], bins=np.linspace(0,1,100),**trainSignalPlot)
ax.hist(trainBackground['infos'][:,6], bins=np.linspace(0,1,100),**trainBackgroundPlot)
ax.hist(recoFailMuonsDY['infos'][:,6], bins=np.linspace(0,1,100),**recoFailMuonsDYPlot)
ax.hist(recoFailMuonsData['infos'][:,6], bins=np.linspace(0,1,100),**recoFailMuonsDataPlot)
ax.hist(recoMuonsData['infos'][:,6], bins=np.linspace(0,1,100),**recoMuonsDataPlot)

ax.set_xlim(0,1)
ax.set_xlabel(r"deltaRToClosestMuon")
ax.set_yscale('log')
ax.legend()

fig.tight_layout()
